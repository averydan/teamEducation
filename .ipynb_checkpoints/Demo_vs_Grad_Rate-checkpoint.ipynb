# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# %%
school_demo_df = pd.read_csv("Resources/cleanschooldemographics2015_revised.csv", na_values=['***'])
school_demo_df.head()
# Out:
#    Corp ID                         Corporation Name  \
# 0       15          Adams Central Community Schools
# 1     5265  Alexandria Community School Corporation
# 2     5275    Anderson Community School Corporation
# 3     5470                  Argos Community Schools
# 4     2435   Attica Consolidated School Corporation
#
#    Native American Cohort Count  Native American Graduates  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
#
#   Native American Grad Rate  Asian Cohort Count  Asian Graduates  \
# 0                       NaN                 NaN              NaN
# 1                       NaN                 NaN              NaN
# 2                       NaN                 NaN              NaN
# 3                       NaN                 NaN              NaN
# 4                       NaN                 NaN              NaN
#
#   Asian Grad Rate  Black Cohort Count  Black Graduates  ...  \
# 0             NaN                 NaN              NaN  ...
# 1             NaN                 NaN              NaN  ...
# 2             NaN               104.0             93.0  ...
# 3             NaN                 NaN              NaN  ...
# 4             NaN                 NaN              NaN  ...
#
#   English Language Learner Grad Rate  Female Cohort Count  Female Graduates  \
# 0                                NaN                 49.0              47.0
# 1                                NaN                 58.0              52.0
# 2                                NaN                204.0             189.0
# 3                                NaN                 21.0              15.0
# 4                                NaN                 34.0              34.0
#
#   Female Grad Rate  Male Cohort Count  Male Graduates Male Grad Rate  \
# 0           95.90%               46.0            43.0         93.50%
# 1           89.70%               54.0            46.0         85.20%
# 2           92.60%              190.0           164.0         86.30%
# 3           71.40%               25.0            19.0         76.00%
# 4          100.00%               34.0            33.0         97.10%
#
#    Total Cohort Count  Total Graduates  Total Grad Rate
# 0                  95               90           94.70%
# 1                 112               98           87.50%
# 2                 394              353           89.60%
# 3                  46               34           73.90%
# 4                  68               67           98.50%
#
# [5 rows x 50 columns]

# %%
corp_name = school_demo_df['Corporation Name']
num_white = school_demo_df['White Cohort Count'].dropna()
cohort_total = school_demo_df['Total Cohort Count']
num_non_white = cohort_total - num_white
percent_white = num_white / cohort_total * 100
percent_non_white = num_non_white / cohort_total * 100
grad_rate = school_demo_df['Total Grad Rate'].str.replace('%','').astype(np.float64)

condenced_demo = pd.DataFrame({
    'Corporation Name': corp_name,
    'White Students' : num_white,
    'Total Cohort': cohort_total,
    'Percent White': percent_white,
    'Percent Non-White': percent_non_white,
    'Grad Rate': grad_rate
})
condenced_demo.dropna()
condenced_demo.isnull()
# Out:
#      Corporation Name  White Students  Total Cohort  Percent White  \
# 0               False           False         False          False
# 1               False           False         False          False
# 2               False           False         False          False
# 3               False           False         False          False
# 4               False           False         False          False
# ..                ...             ...           ...            ...
# 263             False           False         False          False
# 264             False           False         False          False
# 265             False           False         False          False
# 266             False           False         False          False
# 267             False           False         False          False
#
#      Percent Non-White  Grad Rate
# 0                False      False
# 1                False      False
# 2                False      False
# 3                False      False
# 4                False      False
# ..                 ...        ...
# 263              False      False
# 264              False      False
# 265              False      False
# 266              False      False
# 267              False      False
#
# [268 rows x 6 columns]

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(percent_white,grad_rate)
regress_values = percent_white * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.figure(figsize=(10,8))
plt.scatter(percent_white,grad_rate, c=percent_non_white, edgecolors="grey")
plt.plot(percent_white,regress_values,"r-")
plt.annotate(line_eq,(40,60),fontsize=15,color="red")
plt.colorbar()
plt.show()
