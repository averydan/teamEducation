# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import linregress

# %%
expenses_15 = pd.read_csv("Resources/2015Expenditures.csv")
poverty = pd.read_csv("Resources/combined_poverty_rate_revised.csv")
grad_rate_15 = pd.read_csv("Resources/2015_grad_rates_revised.csv")
poverty_15 = poverty["2015 Poverty Rate"]
expenses = expenses_15["TOTALEXP"]
grad_rate = grad_rate_15["State Grad Rate"].str.replace("%","").astype(np.float64) 

expenses.isnull().sum()
# Out:
# 3

# %%
plt.scatter(grad_rate,expenses, edgecolors="black")

cc_expenses_2015 = round(st.pearsonr(grad_rate,expenses)[0],2)
print(f"The correlation coefficient between non-waiver graduation rate and cohort size is {cc_expenses_2015}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-2d45a41f1dd8> in <module>
#       1 plt.scatter(grad_rate,expenses, edgecolors="black")
#       2
# ----> 3 cc_expenses_2015 = round(st.pearsonr(grad_rate,expenses)[0],2)
#       4 print(f"The correlation coefficient between non-waiver graduation rate and cohort size is {cc_expenses_2015}")
#       5
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/scipy/stats/stats.py in pearsonr(x, y)
#    3529     # [-5e210, 5e210, 3e200, -3e200]
#    3530     normxm = linalg.norm(xm)
# -> 3531     normym = linalg.norm(ym)
#    3532
#    3533     threshold = 1e-13
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/scipy/linalg/misc.py in norm(a, ord, axis, keepdims, check_finite)
#     140     # Differs from numpy only in non-finite handling and the use of blas.
#     141     if check_finite:
# ...
